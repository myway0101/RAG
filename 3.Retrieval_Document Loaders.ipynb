# %%
# !pip install -q langchain pypdf unstructured pdf2image docx2txt pdfminer
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 35.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -q langchain-community # Install the langchain-community package
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 31.2 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Document Loaders

# %% [markdown]
# Document Loader는 다양한 형식의 문서를 불러오고 이를 Langchain에 결합하기 쉬운 텍스트 형태로 변환하는 기능을 합니다. 이를 통해 사용자는 txt. 형식의 문서 뿐만 아니라 pdf, word, ppt, xlsx, csv 등 거의 모든 형식의 문서를 기반으로 LLM을 구동할 수 있습니다.

# %% [markdown]
# #### URL Document Loader

# %% [markdown]
# LangChain은 웹에 기록된 글도 텍스트 형식으로 가져와 LLM에 활용할 수 있습니다. 대표적인 URL Loader는 WebBaseLoader와 UnstructuredURLLoader가 있습니다.

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://n.news.naver.com/mnews/article/021/0002691982")

data = loader.load() #로딩시 리스트 값으로 가져옴
print(data[0].page_content) #리스트 첫번째 값을 가져옴, url의 모든 콘텐츠를 가져옴
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# 무서운 발전 속도…오픈AI ‘GPT-5’ 5월 출시
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 본문 바로가기
#
#
#
#
#
#
# NAVER
#
# 뉴스
#
#
# 엔터
#
#
#
#
# 스포츠
#
#
#
#
# 날씨
#
#
#
#
# 프리미엄
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
#
#
# 언론사별
#
#
# 정치
#
#
# 경제
#
#
# 사회
#
#
# 생활/문화
#
#
# IT/과학
#
#
# 세계
#
#
# 랭킹
#
#
# 신문보기
#
#
# 오피니언
#
#
# TV
#
#
# 팩트체크
#
#
# 알고리즘 안내
#
#
# 정정보도 모음
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 문화일보
#
# 문화일보
#
#
# 구독
#
# 문화일보 언론사 구독되었습니다. 메인 뉴스판에서  주요뉴스를  볼 수 있습니다.
# 보러가기
#
#
# 문화일보 언론사 구독 해지되었습니다.
#
#
#
#
# 무서운 발전 속도…오픈AI ‘GPT-5’ 5월 출시
#
#
#
#
# 입력2025.02.22. 오전 8:27
#
# 기사원문
#
#
#
#
#
# 김호준 기자
#
#
#
#
#
#
#
#
# 김호준 기자
#
#
#
#
# 김호준 기자
#
# 구독
# 구독중
#
#
#
#
# 구독자
# 0
#
#
# 응원수
# 0
#
#
#
# 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 추천
#
#
#
#
# 쏠쏠정보
# 0
#
#
#
#
# 흥미진진
# 0
#
#
#
#
# 공감백배
# 0
#
#
#
#
# 분석탁월
# 0
#
#
#
#
# 후속강추
# 0
#
#
#
#
#
#
# 댓글
#
#
#
#
#
# 본문 요약봇
#
#
#
# 본문 요약봇도움말
# ...

# %% [markdown]
# #### PDF Document Loader

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/drive/MyDrive/2025 외부 LLM/자료/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf")
pages = loader.load_and_split() #페이지별로 잘라서 모아 놓은것

# %%
print(len(pages))
# Out:
# 18

# %%
pages #PDF의 모든 페이지
# Out:
# [Document(metadata={'producer': 'Hancom PDF 1.3.0.538', 'creator': 'Hancom PDF 1.3.0.538', 'creationdate': '2022-07-29T09:03:16+09:00', 'author': 'kmd kdy', 'moddate': '2022-07-29T09:03:16+09:00', 'pdfversion': '1.4', 'source': '/content/drive/MyDrive/2025 외부 LLM/자료/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf', 'total_pages': 18, 'page': 0, 'page_label': '1'}, page_content='혁신성장 정책금융 동향 : ICT 산업을 중심으로\n  CIS이슈리포트 2022-2호 | 1 |\n<요  약>▶혁신성장 정책금융기관*은 혁신성장산업 영위기업을 발굴·지원하기 위한 정책금융 가이드라인**에 따라 혁신성장 기술분야에 대한 금융지원을 강화하고 있음     * 산업은행, 기업은행, 수출입은행, 신용보증기금, 기술보증기금, 중소벤처기업진흥공단, 무역보험공사 등 11개 기관    ** 혁신성장 정책금융 지원 대상을 판단하는 기준으로, ‘9대 테마 – 46개 분야 – 296개 품목’으로 구성￮정책금융기관의 혁신성장 정책금융 공급규모는 2017년 24.1조 원에서 2021년 85.4조 원으로 크게 증가하여 국내 산업 구조의 미래 산업으로의 전환을 충실히 지원하고 있음￮본 보고서는 ICT 산업의 정책금융 지원 트렌드를 파악하고, 혁신성장 정책금융이 집중되는 주요 품목의 기술·시장 동향을 분석함▶혁신성장 ICT 산업은 정보통신(6개 분야, 47개 품목), 전기전자(5개 분야, 27개 품목), 센서측정(3개 분야, 19개 품목) 테마로 구성되며, 혁신성장 정책금융기관의 공급액 규모는 2021년 말 기준 16.9조 원으로 2017년 이후 연평균 39.2% 지속 증가하고 
# ...

# %%
print(pages[0])
# Out:
# page_content='혁신성장 정책금융 동향 : ICT 산업을 중심으로
#   CIS이슈리포트 2022-2호 | 1 |
# <요  약>▶혁신성장 정책금융기관*은 혁신성장산업 영위기업을 발굴·지원하기 위한 정책금융 가이드라인**에 따라 혁신성장 기술분야에 대한 금융지원을 강화하고 있음     * 산업은행, 기업은행, 수출입은행, 신용보증기금, 기술보증기금, 중소벤처기업진흥공단, 무역보험공사 등 11개 기관    ** 혁신성장 정책금융 지원 대상을 판단하는 기준으로, ‘9대 테마 – 46개 분야 – 296개 품목’으로 구성￮정책금융기관의 혁신성장 정책금융 공급규모는 2017년 24.1조 원에서 2021년 85.4조 원으로 크게 증가하여 국내 산업 구조의 미래 산업으로의 전환을 충실히 지원하고 있음￮본 보고서는 ICT 산업의 정책금융 지원 트렌드를 파악하고, 혁신성장 정책금융이 집중되는 주요 품목의 기술·시장 동향을 분석함▶혁신성장 ICT 산업은 정보통신(6개 분야, 47개 품목), 전기전자(5개 분야, 27개 품목), 센서측정(3개 분야, 19개 품목) 테마로 구성되며, 혁신성장 정책금융기관의 공급액 규모는 2021년 말 기준 16.9조 원으로 2017년 이후 연평균 39.2% 지속 증가하고 있음￮ICT 산업의 공급액 규모 비중은 혁신성장 정책금융 총 공급 규모의 약 20% 수준임      * (‘17)18.7% → (’18)20.7%  → (’19)18.5%  → (’20)20.3%  → (’21)19.8%
# 혁신성장 정책금융 동향 :ICT 산업을 중심으로
# ...

# %%
print(pages[0].page_content)
# Out:
# 혁신성장 정책금융 동향 : ICT 산업을 중심으로
#   CIS이슈리포트 2022-2호 | 1 |
# <요  약>▶혁신성장 정책금융기관*은 혁신성장산업 영위기업을 발굴·지원하기 위한 정책금융 가이드라인**에 따라 혁신성장 기술분야에 대한 금융지원을 강화하고 있음     * 산업은행, 기업은행, 수출입은행, 신용보증기금, 기술보증기금, 중소벤처기업진흥공단, 무역보험공사 등 11개 기관    ** 혁신성장 정책금융 지원 대상을 판단하는 기준으로, ‘9대 테마 – 46개 분야 – 296개 품목’으로 구성￮정책금융기관의 혁신성장 정책금융 공급규모는 2017년 24.1조 원에서 2021년 85.4조 원으로 크게 증가하여 국내 산업 구조의 미래 산업으로의 전환을 충실히 지원하고 있음￮본 보고서는 ICT 산업의 정책금융 지원 트렌드를 파악하고, 혁신성장 정책금융이 집중되는 주요 품목의 기술·시장 동향을 분석함▶혁신성장 ICT 산업은 정보통신(6개 분야, 47개 품목), 전기전자(5개 분야, 27개 품목), 센서측정(3개 분야, 19개 품목) 테마로 구성되며, 혁신성장 정책금융기관의 공급액 규모는 2021년 말 기준 16.9조 원으로 2017년 이후 연평균 39.2% 지속 증가하고 있음￮ICT 산업의 공급액 규모 비중은 혁신성장 정책금융 총 공급 규모의 약 20% 수준임      * (‘17)18.7% → (’18)20.7%  → (’19)18.5%  → (’20)20.3%  → (’21)19.8%
# 혁신성장 정책금융 동향 :ICT 산업을 중심으로
# 오동찬 선임조사역 (dcoh@kcredit.or.kr)

# %% [markdown]
# #### Word Document Loader

# %%
from langchain.document_loaders import Docx2txtLoader
loader = Docx2txtLoader("/content/drive/MyDrive/2025 외부 LLM/자료/해커톤.docx")
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/2025 외부 LLM/자료/해커톤.docx'}, page_content='<식단 기반 영양제 추천 서비스>\n\n\n\n아이디어 \n\n 일일 섭취량 기반 필요 영양성분 / 초과 영양성분 알림 서비스\n\n \n\n기획 배경 \n\n의학이 발달함에 따라 기대 수명 증가\n\n\n\n단순히 오래 사는 것이 아닌 건강하게 오래사는 법에 대한 관심 증가\n\n\n\n실질적으로 모든 필요 영양성분을 식단을 통해 섭취 불가\n\n\n\n가지고 있는 질병 및 건강 증진을 목적으로 사람들의 영양제 섭취량 증가\n\n\n\n필요 영양제와 복용법에 관한 관심 증가, 오남용으로 인한 부작용에 대한 걱정 / 너무 다양한 정보로 인한 혼란 야기\n\n필요 영양제와 복용법에 관한 관심 증가, 무분별한 정보로 인한 혼란 야기, 오남용 증가\n\n\n\n1인 가구 및 외식 비중의 증대로 섭취한 음식 정보에 대한 정확한 인지 불가능\n\n \n\n\n\n서비스 구성\n\n사전에 사용자 정보 등록\n\n성별, 나이, 키, 체중, 직업, 활동량, 야외활동량 (햇빛 노출) , 가지고 있는 질병, 기타 개선을 바라는 증상 등\n\n\n\n하루 섭취 정보 기입\n\n인터페이스 구성을 통한 직접 업로드 (ex : 김치찌개, 밥, 고등어 조림 등)  \n\n사진 업로드 : 기계 학습을 통한 이미지 학습으로 사진 업로드시 해당 음식과 자동적으로 매칭\n\n라이다 센서를 통한 인식 (라이다 센서를 통해 섭취하고자 하는 음식 업로드 / 활용 가능여부 체크 필요)\n\n\n\n영양 성분 부족 / 초과시 발생 가능한 증상 및 부작용 정보제공\n\n영양제일 경우 섭취량을 초과하지 않는 함량을 선별하여 정보 제공 혹은 검색 할 수 있도록 분류\n\n\n\n업로드한 섭취 정보를 기반 일일 권장량 대비 섭취 영양성분 확인\n\n\n\n사전에 입력한 사용자 정보를 바탕으로 추가로 필요한 영양성분 알림 (해당 영양성분 섭
# ...

# %%
data[0].metadata
# Out:
# {'source': '/content/drive/MyDrive/2024-2/빅데이터서비스/자료/해커톤.docx'}

# %%
data[0].page_content
# Out:
# '<식단 기반 영양제 추천 서비스>\n\n\n\n아이디어 \n\n 일일 섭취량 기반 필요 영양성분 / 초과 영양성분 알림 서비스\n\n \n\n기획 배경 \n\n의학이 발달함에 따라 기대 수명 증가\n\n\n\n단순히 오래 사는 것이 아닌 건강하게 오래사는 법에 대한 관심 증가\n\n\n\n실질적으로 모든 필요 영양성분을 식단을 통해 섭취 불가\n\n\n\n가지고 있는 질병 및 건강 증진을 목적으로 사람들의 영양제 섭취량 증가\n\n\n\n필요 영양제와 복용법에 관한 관심 증가, 오남용으로 인한 부작용에 대한 걱정 / 너무 다양한 정보로 인한 혼란 야기\n\n필요 영양제와 복용법에 관한 관심 증가, 무분별한 정보로 인한 혼란 야기, 오남용 증가\n\n\n\n1인 가구 및 외식 비중의 증대로 섭취한 음식 정보에 대한 정확한 인지 불가능\n\n \n\n\n\n서비스 구성\n\n사전에 사용자 정보 등록\n\n성별, 나이, 키, 체중, 직업, 활동량, 야외활동량 (햇빛 노출) , 가지고 있는 질병, 기타 개선을 바라는 증상 등\n\n\n\n하루 섭취 정보 기입\n\n인터페이스 구성을 통한 직접 업로드 (ex : 김치찌개, 밥, 고등어 조림 등)  \n\n사진 업로드 : 기계 학습을 통한 이미지 학습으로 사진 업로드시 해당 음식과 자동적으로 매칭\n\n라이다 센서를 통한 인식 (라이다 센서를 통해 섭취하고자 하는 음식 업로드 / 활용 가능여부 체크 필요)\n\n\n\n영양 성분 부족 / 초과시 발생 가능한 증상 및 부작용 정보제공\n\n영양제일 경우 섭취량을 초과하지 않는 함량을 선별하여 정보 제공 혹은 검색 할 수 있도록 분류\n\n\n\n업로드한 섭취 정보를 기반 일일 권장량 대비 섭취 영양성분 확인\n\n\n\n사전에 입력한 사용자 정보를 바탕으로 추가로 필요한 영양성분 알림 (해당 영양성분 섭취가 가능한 음식, 조리법 및 영양제 정보 제공 서비스 / 영양제일 경우 함량, 가격대별 정보제공)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
# ...

# %% [markdown]
# #### CSV Document Loader

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader(file_path='/content/drive/MyDrive/2025 외부 LLM/자료/최종 필터링 데이터 (호텔, 지형) - 시트3.csv', csv_args={
    'delimiter': ',',
    'quotechar': '"',
    'fieldnames': ['ID', 'Name', 'Position', 'Height', 'Weight', 'Sponsorship Earnings', 'Shoe Sponsor', 'Career Stage', 'Age']
})

data = loader.load()

# %%
data[:10]
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/2025 외부 LLM/자료/최종 필터링 데이터 (호텔, 지형) - 시트3.csv', 'row': 0}, page_content='ID: \nName: \nPosition: \nHeight: \nWeight: \nSponsorship Earnings: \nShoe Sponsor: None\nCareer Stage: None\nAge: None'),
#  Document(metadata={'source': '/content/drive/MyDrive/2025 외부 LLM/자료/최종 필터링 데이터 (호텔, 지형) - 시트3.csv', 'row': 1}, page_content='ID: Country\nName: City\nPosition: hotel\nHeight: mountain\nWeight: beach\nSponsorship Earnings: plain\nShoe Sponsor: None\nCareer Stage: None\nAge: None'),
#  Document(metadata={'source': '/content/drive/MyDrive/2025 외부 LLM/자료/최종 필터링 데이터 (호텔, 지형) - 시트3.csv', 'row': 2}, page_content='ID: Italy\nName: Agrigento\nPosition: 237\nHeight: 1\nWeight: 0\nSponsorship Earnings: 0\nShoe Sponsor: None\nCareer Stage: None\nAge: None'),
# ...
